# %% [markdown]
# # Imports

# %% [markdown]
# # Ingesting Ausfb pages

# %%
"""Load html from files, clean up, split, ingest into Weaviate."""
import pickle

from langchain.document_loaders import ReadTheDocsLoader
from langchain.embeddings import OpenAIEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores.faiss import FAISS


def ingest_docs(location = "langchain.readthedocs.io/en/latest/"):
    """Get documents from web pages."""
    loader = ReadTheDocsLoader(location)
    raw_documents = loader.load()
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=1000,
        chunk_overlap=200,
    )
    documents = text_splitter.split_documents(raw_documents)
    embeddings = OpenAIEmbeddings()
    vectorstore = FAISS.from_documents(documents, embeddings)

    # Save vectorstore
    with open("vectorstore.pkl", "wb") as f:
        pickle.dump(vectorstore, f)


if __name__ == "__main__":
    ingest_docs()
# Out:
# /home/ravi/anaconda3/lib/python3.10/site-packages/langchain/document_loaders/readthedocs.py:48: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 48 of the file /home/ravi/anaconda3/lib/python3.10/site-packages/langchain/document_loaders/readthedocs.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   _ = BeautifulSoup(
# ...

# %%
ls
# Out:
# archive/         ingest.sh*                 __pycache__/      templates/
# assets/          langchain.readthedocs.io/  query_data.py     Untitled.ipynb
# callback.py      LICENSE                    README.md         vectorstore.pkl
# environment.yml  main.py                    requirements.txt  www.aubank.in/
# ingest.py        Makefile                   schemas.py

# %%
ingest_docs('www.aubank.in')
# Out:
# /home/ravi/anaconda3/lib/python3.10/site-packages/langchain/document_loaders/readthedocs.py:75: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 75 of the file /home/ravi/anaconda3/lib/python3.10/site-packages/langchain/document_loaders/readthedocs.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(data, **self.bs_kwargs)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ingest_docs('www.aubank.in')
#
# Cell In[1], line 20, in ingest_docs(location)
# ...

# %%
location = 'www.aubank.in'

# %%
loader = ReadTheDocsLoader(location)

# %%
raw_documents = loader.load()

# %%
raw_documents
# Out:
# [Document(page_content='', metadata={'source': 'www.aubank.in/robots.txt'}),
#  Document(page_content='', metadata={'source': 'www.aubank.in/index.html'}),
#  Document(page_content='', metadata={'source': 'www.aubank.in/personal-banking/savings-account/au-platinum'})]

# %%
text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=1000,
        chunk_overlap=200,
    )

# %%
documents = text_splitter.split_documents(raw_documents)

# %%
documents
# Out:
# []

# %%
raw_documents[0].
# Out:
# ''

# %%
from langchain.document_loaders import BSHTMLLoader

# %%
# loader = BSHTMLLoader("www.aubank.in/index.html")
loader = BSHTMLLoader("www.aubank.in/personal-banking/savings-account/au-platinum")

data = loader.load()
print(data[0].)
# Out:
# AU Platinum - Premium Family Banking Program | AU Small Finance Bank
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Gateway to Digital Life. Download AU 0101.
#
#
#
#
#
#
#
#
#
#
#
#
#
# Login
#
# AU 0101 NetBanking
# Corporate Netbanking
#
#
#
#
#
#
#  About Us
#  Investors
#  Careers
#  Debit Card Services
#  Interest Rates
#  Apply Now
#  Locate Us
#  Contact Us
#
#
#
#
#
#   Personal
#
#
#   Premium
#
#
#   Business
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Make Payment
#
#
#
#
# AU 0101
#
#
#
#
#
#
#  AU 0101 App
#
#
#
#
#
#
#
#
#
# AU 0101 App
#
# Your gateway to the worldof smart banking
#
#
#
#
# Explore Now
#
#
#
#
#
#
#
#
#
#
#
#
# AU 0101 NetBanking
#
#
#
#
#
#
#
#
#
# AU 0101 NetBanking
#
# Your bank is where you are
#
#
#
#
# Explore Now
#
#
#
#
#
#
#
#
#
#
#
#
# Video Banking
#
#
#
#
#
#
#
#
#
# Video Banking
#
# Reinventing
# Banking for you
#
#
#
#
# Know More
#
#
#
#
#
#
#
#
#
#
#
#  WhatsApp Banking
#
#
#
#
#
#
#
# ...

# %%
documents = text_splitter.split_documents(data)

# %%
for sp in splitted:
    if not sp.page_content.isspace():
        print(sp.page_content)
        print('------------------------------')
# Out:
# AU Platinum - Premium Family Banking Program | AU Small Finance Bank
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Gateway to Digital Life. Download AU 0101.
#
#
#
#
#
#
#
#
#
#
#
#
#
# Login
#
# AU 0101 NetBanking
# Corporate Netbanking
#
#
#
#
#
#
#  About Us
#  Investors
#  Careers
#  Debit Card Services
#  Interest Rates
#  Apply Now
#  Locate Us
#  Contact Us
#
#
#
#
#
#   Personal
#
#
#   Premium
#
#
#   Business
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Make Payment
#
#
#
#
# AU 0101
#
#
#
#
#
#
#  AU 0101 App
#
#
#
#
#
#
#
#
#
# AU 0101 App
#
# Your gateway to the worldof smart banking
#
#
#
#
# Explore Now
#
#
#
#
#
#
#
#
#
#
#
#
# AU 0101 NetBanking
#
#
#
#
#
#
#
#
#
# AU 0101 NetBanking
#
# Your bank is where you are
#
#
#
#
# Explore Now
#
#
#
#
#
#
#
#
#
#
#
#
# Video Banking
#
#
#
#
#
#
#
#
#
# Video Banking
#
# Reinventing
# Banking for you
#
#
#
#
# Know More
#
#
#
#
#
#
#
#
#
#
#
#  WhatsApp Banking
#
#
#
#
#
#
#
# ...

# %%
"   \n\n\n\n  \t\t\n   ".isspace()
# Out:
# True

# %%
embeddings = OpenAIEmbeddings()

# %%
vectorstore = FAISS.from_documents(documents, embeddings)

# %%
with open("ausfb.pkl", "wb") as f:
    pickle.dump(vectorstore, f)

# %%
ls
# Out:
# archive/         ingest.py                  Makefile          schemas.py
# assets/          ingest.sh*                 __pycache__/      templates/
# ausfb.pkl        langchain.readthedocs.io/  query_data.py     Untitled.ipynb
# callback.py      LICENSE                    README.md         vectorstore.pkl
# environment.yml  main.py                    requirements.txt  www.aubank.in/
